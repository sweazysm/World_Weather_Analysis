# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import random
from datetime import datetime
from config import weather_api_key
from config import g_key
from scipy.stats import linregress
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rayagada
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | vila do maio
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | atar
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | crotone
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | anzio
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | santa isabel
# Processing Record 16 of Set 1 | menongue
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | norsup
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | missoula
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | asau
# Processing Record 23 of Set 1 | lata
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | nuuk
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | kahului
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | svetlogorsk
# Processing Record 35 of Set 1 | port hardy
# Processing Record 36 of Set 1 | tiruvottiyur
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | ploemeur
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | flinders
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | sobreira
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | yeppoon
# Processing Record 6 of Set 2 | fort-shevchenko
# Processing Record 7 of Set 2 | komsomolskiy
# Processing Record 8 of Set 2 | margate
# Processing Record 9 of Set 2 | marsa matruh
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | asheville
# Processing Record 12 of Set 2 | okhotsk
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | flin flon
# Processing Record 15 of Set 2 | shubarkuduk
# Processing Record 16 of Set 2 | kaffrine
# Processing Record 17 of Set 2 | sault sainte marie
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | nara
# Processing Record 20 of Set 2 | faya
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | muravlenko
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | tonstad
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 2 | nhulunbuy
# Processing Record 31 of Set 2 | taft
# Processing Record 32 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 2 | imeni poliny osipenko
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | virginia beach
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | bilma
# Processing Record 39 of Set 2 | raton
# Processing Record 40 of Set 2 | storm lake
# Processing Record 41 of Set 2 | yerbogachen
# Processing Record 42 of Set 2 | porto santo
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | broken hill
# Processing Record 45 of Set 2 | te anau
# Processing Record 46 of Set 2 | channel-port aux basques
# Processing Record 47 of Set 2 | marrakesh
# Processing Record 48 of Set 2 | tongsa
# City not found. Skipping...
# Processing Record 49 of Set 2 | altay
# Processing Record 50 of Set 2 | camacha
# Processing Record 1 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 3 | samarkand
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | luanda
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | vinh
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | port blair
# Processing Record 12 of Set 3 | marawi
# Processing Record 13 of Set 3 | uusikaupunki
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | narimanov
# Processing Record 19 of Set 3 | yaan
# Processing Record 20 of Set 3 | araouane
# Processing Record 21 of Set 3 | sinnamary
# Processing Record 22 of Set 3 | koslan
# Processing Record 23 of Set 3 | mizdah
# Processing Record 24 of Set 3 | mount gambier
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | usta muhammad
# Processing Record 27 of Set 3 | monrovia
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | abilene
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | aljezur
# Processing Record 32 of Set 3 | west odessa
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | am timan
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | ugoofaaru
# Processing Record 41 of Set 3 | niwari
# Processing Record 42 of Set 3 | singapore
# Processing Record 43 of Set 3 | chulym
# Processing Record 44 of Set 3 | taoudenni
# Processing Record 45 of Set 3 | danville
# Processing Record 46 of Set 3 | santa marta
# Processing Record 47 of Set 3 | winslow
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | havoysund
# Processing Record 1 of Set 4 | nanortalik
# Processing Record 2 of Set 4 | corinto
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | aksarka
# Processing Record 5 of Set 4 | warri
# Processing Record 6 of Set 4 | westport
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | tunxi
# City not found. Skipping...
# Processing Record 9 of Set 4 | seoul
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | kathu
# Processing Record 12 of Set 4 | lago da pedra
# Processing Record 13 of Set 4 | birjand
# Processing Record 14 of Set 4 | carballo
# Processing Record 15 of Set 4 | mosquera
# Processing Record 16 of Set 4 | neuquen
# Processing Record 17 of Set 4 | ivanjica
# Processing Record 18 of Set 4 | port-gentil
# Processing Record 19 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 4 | black river
# Processing Record 21 of Set 4 | octeville
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | fairbanks
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | lakes entrance
# Processing Record 26 of Set 4 | gabu
# Processing Record 27 of Set 4 | shelburne
# Processing Record 28 of Set 4 | qarchi gak
# Processing Record 29 of Set 4 | goderich
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | gat
# Processing Record 32 of Set 4 | benemerito de las americas
# Processing Record 33 of Set 4 | beira
# Processing Record 34 of Set 4 | cariacica
# Processing Record 35 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 36 of Set 4 | pangnirtung
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | todos santos
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | lumberton
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 4 | rio grande
# Processing Record 44 of Set 4 | dwarka
# Processing Record 45 of Set 4 | xuddur
# Processing Record 46 of Set 4 | belyy yar
# Processing Record 47 of Set 4 | boajibu
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | port alfred
# Processing Record 50 of Set 4 | goundam
# Processing Record 1 of Set 5 | port elizabeth
# Processing Record 2 of Set 5 | acapulco
# Processing Record 3 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | shingu
# Processing Record 7 of Set 5 | sayyan
# Processing Record 8 of Set 5 | emba
# Processing Record 9 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | saskylakh
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | vila franca do campo
# Processing Record 17 of Set 5 | letnyaya stavka
# Processing Record 18 of Set 5 | emilio carranza
# Processing Record 19 of Set 5 | avarua
# Processing Record 20 of Set 5 | necochea
# Processing Record 21 of Set 5 | felipe carrillo puerto
# Processing Record 22 of Set 5 | barrow
# Processing Record 23 of Set 5 | naze
# Processing Record 24 of Set 5 | itarema
# Processing Record 25 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | san patricio
# Processing Record 28 of Set 5 | lensk
# Processing Record 29 of Set 5 | south san francisco
# Processing Record 30 of Set 5 | vilyuysk
# Processing Record 31 of Set 5 | dawei
# Processing Record 32 of Set 5 | onega
# Processing Record 33 of Set 5 | sur
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | itamarandiba
# Processing Record 37 of Set 5 | kampil
# Processing Record 38 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | cabedelo
# Processing Record 41 of Set 5 | vao
# Processing Record 42 of Set 5 | bathsheba
# Processing Record 43 of Set 5 | plettenberg bay
# Processing Record 44 of Set 5 | matara
# Processing Record 45 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 5 | pochutla
# Processing Record 47 of Set 5 | nouadhibou
# Processing Record 48 of Set 5 | marsabit
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | tuatapere
# Processing Record 1 of Set 6 | marsh harbour
# Processing Record 2 of Set 6 | natal
# Processing Record 3 of Set 6 | choma
# Processing Record 4 of Set 6 | matamoros
# Processing Record 5 of Set 6 | rochegda
# Processing Record 6 of Set 6 | yumen
# Processing Record 7 of Set 6 | puerto ayora
# Processing Record 8 of Set 6 | along
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | caravelas
# Processing Record 11 of Set 6 | bangassou
# Processing Record 12 of Set 6 | pasco
# Processing Record 13 of Set 6 | tartagal
# Processing Record 14 of Set 6 | portel
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | kavieng
# Processing Record 17 of Set 6 | kismayo
# Processing Record 18 of Set 6 | alofi
# Processing Record 19 of Set 6 | tromso
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | hay river
# Processing Record 22 of Set 6 | kidal
# Processing Record 23 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 6 | xapuri
# Processing Record 25 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 6 | hobyo
# Processing Record 27 of Set 6 | saint-pierre
# Processing Record 28 of Set 6 | aswan
# Processing Record 29 of Set 6 | tiksi
# Processing Record 30 of Set 6 | mar del plata
# Processing Record 31 of Set 6 | spruce grove
# Processing Record 32 of Set 6 | kamennomostskiy
# Processing Record 33 of Set 6 | tadine
# Processing Record 34 of Set 6 | zapolyarnyy
# Processing Record 35 of Set 6 | thunder bay
# Processing Record 36 of Set 6 | kudahuvadhoo
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | chulman
# Processing Record 39 of Set 6 | mahibadhoo
# Processing Record 40 of Set 6 | manggar
# Processing Record 41 of Set 6 | maceio
# Processing Record 42 of Set 6 | tungor
# Processing Record 43 of Set 6 | cabo san lucas
# Processing Record 44 of Set 6 | riyadh
# Processing Record 45 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 46 of Set 6 | anacortes
# Processing Record 47 of Set 6 | christchurch
# Processing Record 48 of Set 6 | zhangjiakou
# Processing Record 49 of Set 6 | rio claro
# Processing Record 50 of Set 6 | halifax
# Processing Record 1 of Set 7 | la orilla
# Processing Record 2 of Set 7 | tautira
# Processing Record 3 of Set 7 | victoria
# Processing Record 4 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 7 | guekedou
# City not found. Skipping...
# Processing Record 6 of Set 7 | bihariganj
# Processing Record 7 of Set 7 | osmena
# Processing Record 8 of Set 7 | maryville
# Processing Record 9 of Set 7 | petatlan
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | hithadhoo
# Processing Record 12 of Set 7 | harnosand
# Processing Record 13 of Set 7 | honiara
# Processing Record 14 of Set 7 | udachnyy
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | murray bridge
# Processing Record 17 of Set 7 | makat
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | nishihara
# Processing Record 20 of Set 7 | scarborough
# Processing Record 21 of Set 7 | yulara
# Processing Record 22 of Set 7 | kiunga
# Processing Record 23 of Set 7 | northam
# Processing Record 24 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 7 | mitsamiouli
# Processing Record 26 of Set 7 | denau
# City not found. Skipping...
# Processing Record 27 of Set 7 | labuhan
# Processing Record 28 of Set 7 | batemans bay
# Processing Record 29 of Set 7 | auchi
# Processing Record 30 of Set 7 | batagay
# Processing Record 31 of Set 7 | khurda
# Processing Record 32 of Set 7 | chuy
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | karatuzskoye
# Processing Record 36 of Set 7 | tasiilaq
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | sangar
# Processing Record 39 of Set 7 | ilinskiy
# Processing Record 40 of Set 7 | cidreira
# Processing Record 41 of Set 7 | houston
# Processing Record 42 of Set 7 | nautla
# Processing Record 43 of Set 7 | kruisfontein
# Processing Record 44 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 7 | teocaltiche
# Processing Record 46 of Set 7 | sao gabriel
# Processing Record 47 of Set 7 | mana
# Processing Record 48 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 7 | abu samrah
# Processing Record 50 of Set 7 | agva
# City not found. Skipping...
# Processing Record 1 of Set 8 | sladkovo
# Processing Record 2 of Set 8 | sri aman
# Processing Record 3 of Set 8 | miraflores
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | pangody
# Processing Record 6 of Set 8 | floriano
# Processing Record 7 of Set 8 | changping
# Processing Record 8 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 8 | poum
# Processing Record 12 of Set 8 | breyten
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | dingle
# Processing Record 15 of Set 8 | bairiki
# Processing Record 16 of Set 8 | gamba
# Processing Record 17 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 8 | ouadda
# Processing Record 19 of Set 8 | fauske
# Processing Record 20 of Set 8 | dalvik
# Processing Record 21 of Set 8 | zumpango
# Processing Record 22 of Set 8 | morwell
# Processing Record 23 of Set 8 | saurimo
# Processing Record 24 of Set 8 | buraydah
# Processing Record 25 of Set 8 | ilhabela
# Processing Record 26 of Set 8 | sobolevo
# Processing Record 27 of Set 8 | bac lieu
# Processing Record 28 of Set 8 | port moresby
# Processing Record 29 of Set 8 | hangu
# Processing Record 30 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 31 of Set 8 | tricase
# Processing Record 32 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 8 | mushie
# Processing Record 34 of Set 8 | glazov
# Processing Record 35 of Set 8 | college
# Processing Record 36 of Set 8 | fredericksburg
# Processing Record 37 of Set 8 | olafsvik
# Processing Record 38 of Set 8 | kasongo-lunda
# Processing Record 39 of Set 8 | opuwo
# Processing Record 40 of Set 8 | fomboni
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | kumluca
# Processing Record 43 of Set 8 | khushab
# Processing Record 44 of Set 8 | bafoulabe
# Processing Record 45 of Set 8 | odweyne
# Processing Record 46 of Set 8 | ayan
# Processing Record 47 of Set 8 | oranjemund
# Processing Record 48 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 8 | zyryanka
# Processing Record 50 of Set 8 | suntar
# Processing Record 1 of Set 9 | kedrovyy
# Processing Record 2 of Set 9 | isla mujeres
# Processing Record 3 of Set 9 | abbeville
# Processing Record 4 of Set 9 | nouakchott
# Processing Record 5 of Set 9 | progreso
# Processing Record 6 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 9 | duluth
# Processing Record 8 of Set 9 | mount isa
# Processing Record 9 of Set 9 | chara
# Processing Record 10 of Set 9 | traverse city
# Processing Record 11 of Set 9 | puerto quijarro
# Processing Record 12 of Set 9 | georgetown
# Processing Record 13 of Set 9 | mindelo
# Processing Record 14 of Set 9 | windhoek
# Processing Record 15 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 9 | haines junction
# Processing Record 17 of Set 9 | awjilah
# Processing Record 18 of Set 9 | sioux lookout
# Processing Record 19 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 9 | billings
# Processing Record 21 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 22 of Set 9 | barda
# Processing Record 23 of Set 9 | finnsnes
# Processing Record 24 of Set 9 | avera
# Processing Record 25 of Set 9 | dubbo
# Processing Record 26 of Set 9 | pulandian
# Processing Record 27 of Set 9 | song phi nong
# Processing Record 28 of Set 9 | burewala
# Processing Record 29 of Set 9 | hauterive
# Processing Record 30 of Set 9 | edgewater
# Processing Record 31 of Set 9 | jasper
# Processing Record 32 of Set 9 | deputatskiy
# Processing Record 33 of Set 9 | ust-kut
# Processing Record 34 of Set 9 | puerto del rosario
# Processing Record 35 of Set 9 | pyinmana
# Processing Record 36 of Set 9 | crato
# Processing Record 37 of Set 9 | agnibilekrou
# Processing Record 38 of Set 9 | ocos
# Processing Record 39 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 9 | lerwick
# Processing Record 41 of Set 9 | waddan
# Processing Record 42 of Set 9 | ostrovnoy
# Processing Record 43 of Set 9 | cerritos
# Processing Record 44 of Set 9 | samarai
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | igarka
# Processing Record 47 of Set 9 | mega
# Processing Record 48 of Set 9 | shache
# Processing Record 49 of Set 9 | falmouth
# Processing Record 50 of Set 9 | zhigansk
# Processing Record 1 of Set 10 | davila
# Processing Record 2 of Set 10 | hami
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | isangel
# Processing Record 5 of Set 10 | kaduna
# Processing Record 6 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 10 | port lincoln
# Processing Record 8 of Set 10 | valdivia
# Processing Record 9 of Set 10 | witrivier
# City not found. Skipping...
# Processing Record 10 of Set 10 | muros
# Processing Record 11 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 10 | jacareacanga
# Processing Record 13 of Set 10 | itacare
# Processing Record 14 of Set 10 | barmer
# Processing Record 15 of Set 10 | liverpool
# Processing Record 16 of Set 10 | kochevo
# Processing Record 17 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 10 | beringovskiy
# Processing Record 19 of Set 10 | mitu
# Processing Record 20 of Set 10 | boguchany
# Processing Record 21 of Set 10 | pemangkat
# Processing Record 22 of Set 10 | xining
# Processing Record 23 of Set 10 | havelock
# Processing Record 24 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | basar
# Processing Record 27 of Set 10 | solnechnyy
# Processing Record 28 of Set 10 | litovko
# Processing Record 29 of Set 10 | clarence town
# Processing Record 30 of Set 10 | putina
# Processing Record 31 of Set 10 | hillsborough
# Processing Record 32 of Set 10 | jabbeke
# Processing Record 33 of Set 10 | ritchie
# Processing Record 34 of Set 10 | kantabanji
# Processing Record 35 of Set 10 | iquique
# Processing Record 36 of Set 10 | fort wellington
# Processing Record 37 of Set 10 | brindisi
# Processing Record 38 of Set 10 | kuching
# Processing Record 39 of Set 10 | taksimo
# Processing Record 40 of Set 10 | loikaw
# Processing Record 41 of Set 10 | marzuq
# Processing Record 42 of Set 10 | camopi
# Processing Record 43 of Set 10 | urumqi
# Processing Record 44 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 45 of Set 10 | annau
# Processing Record 46 of Set 10 | kalmunai
# Processing Record 47 of Set 10 | zhezkazgan
# Processing Record 48 of Set 10 | vrangel
# Processing Record 49 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 10 | praia
# Processing Record 1 of Set 11 | cogua
# Processing Record 2 of Set 11 | morondava
# Processing Record 3 of Set 11 | yetkul
# Processing Record 4 of Set 11 | gravelbourg
# Processing Record 5 of Set 11 | arona
# Processing Record 6 of Set 11 | masvingo
# Processing Record 7 of Set 11 | ashland
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | erenhot
# Processing Record 10 of Set 11 | orchard homes
# Processing Record 11 of Set 11 | zharkent
# Processing Record 12 of Set 11 | kashary
# Processing Record 13 of Set 11 | tingo maria
# Processing Record 14 of Set 11 | waingapu
# Processing Record 15 of Set 11 | monino
# Processing Record 16 of Set 11 | porto-vecchio
# Processing Record 17 of Set 11 | pelotas
# Processing Record 18 of Set 11 | salalah
# Processing Record 19 of Set 11 | karratha
# Processing Record 20 of Set 11 | high rock
# Processing Record 21 of Set 11 | qandala
# Processing Record 22 of Set 11 | clearwater
# Processing Record 23 of Set 11 | balkhash
# Processing Record 24 of Set 11 | raigarh
# Processing Record 25 of Set 11 | zabol
# Processing Record 26 of Set 11 | fallon
# Processing Record 27 of Set 11 | youghal
# Processing Record 28 of Set 11 | shimoda
# Processing Record 29 of Set 11 | surt
# Processing Record 30 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 11 | jejuri
# Processing Record 32 of Set 11 | canto do buriti
# Processing Record 33 of Set 11 | amahai
# Processing Record 34 of Set 11 | ler
# Processing Record 35 of Set 11 | severo-yeniseyskiy
# Processing Record 36 of Set 11 | savalou
# Processing Record 37 of Set 11 | karaman
# Processing Record 38 of Set 11 | manacor
# Processing Record 39 of Set 11 | korem
# Processing Record 40 of Set 11 | longyearbyen
# Processing Record 41 of Set 11 | matagami
# Processing Record 42 of Set 11 | kinshasa
# Processing Record 43 of Set 11 | kamaishi
# Processing Record 44 of Set 11 | phrae
# Processing Record 45 of Set 11 | mamallapuram
# Processing Record 46 of Set 11 | morozovsk
# Processing Record 47 of Set 11 | east stroudsburg
# Processing Record 48 of Set 11 | pachmarhi
# Processing Record 49 of Set 11 | walvis bay
# Processing Record 50 of Set 11 | tambacounda
# Processing Record 1 of Set 12 | busayra
# Processing Record 2 of Set 12 | reserva
# Processing Record 3 of Set 12 | sao filipe
# Processing Record 4 of Set 12 | sao sebastiao
# Processing Record 5 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 12 | yibin
# Processing Record 7 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 12 | jos
# Processing Record 9 of Set 12 | pasighat
# Processing Record 10 of Set 12 | lichuan
# Processing Record 11 of Set 12 | swakopmund
# Processing Record 12 of Set 12 | barcelos
# Processing Record 13 of Set 12 | paamiut
# Processing Record 14 of Set 12 | recreio
# Processing Record 15 of Set 12 | maple creek
# Processing Record 16 of Set 12 | eirunepe
# Processing Record 17 of Set 12 | portland
# Processing Record 18 of Set 12 | rantepao
# Processing Record 19 of Set 12 | mahebourg
# Processing Record 20 of Set 12 | rassvet
# Processing Record 21 of Set 12 | burnie
# Processing Record 22 of Set 12 | olga
# Processing Record 23 of Set 12 | bullhead city
# Processing Record 24 of Set 12 | manokwari
# Processing Record 25 of Set 12 | merauke
# Processing Record 26 of Set 12 | zatyshshya
# Processing Record 27 of Set 12 | fukue
# Processing Record 28 of Set 12 | llangefni
# Processing Record 29 of Set 12 | semporna
# Processing Record 30 of Set 12 | hovd
# Processing Record 31 of Set 12 | fengcheng
# Processing Record 32 of Set 12 | namatanai
# Processing Record 33 of Set 12 | berlevag
# Processing Record 34 of Set 12 | pangoa
# Processing Record 35 of Set 12 | acari
# Processing Record 36 of Set 12 | esperance
# Processing Record 37 of Set 12 | coihaique
# Processing Record 38 of Set 12 | nalut
# Processing Record 39 of Set 12 | ravar
# Processing Record 40 of Set 12 | petushki
# Processing Record 41 of Set 12 | grindavik
# Processing Record 42 of Set 12 | yamada
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | pisticci
# Processing Record 45 of Set 12 | nagato
# Processing Record 46 of Set 12 | victor harbor
# Processing Record 47 of Set 12 | dongsheng
# Processing Record 48 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 12 | zelenoborskiy
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | the valley
# Processing Record 2 of Set 13 | maningrida
# Processing Record 3 of Set 13 | luganville
# Processing Record 4 of Set 13 | broome
# Processing Record 5 of Set 13 | maues
# Processing Record 6 of Set 13 | kloulklubed
# Processing Record 7 of Set 13 | gandajika
# Processing Record 8 of Set 13 | sakaiminato
# Processing Record 9 of Set 13 | sumter
# Processing Record 10 of Set 13 | general roca
# Processing Record 11 of Set 13 | kupang
# Processing Record 12 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 13 | healdsburg
# Processing Record 14 of Set 13 | red bluff
# Processing Record 15 of Set 13 | cayenne
# Processing Record 16 of Set 13 | letka
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | itoman
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | alfenas
# Processing Record 21 of Set 13 | jiangkou
# Processing Record 22 of Set 13 | aden
# Processing Record 23 of Set 13 | colesberg
# Processing Record 24 of Set 13 | morehead
# Processing Record 25 of Set 13 | viransehir
# Processing Record 26 of Set 13 | khandyga
# Processing Record 27 of Set 13 | funadhoo
# Processing Record 28 of Set 13 | gryazovets
# Processing Record 29 of Set 13 | askino
# Processing Record 30 of Set 13 | port augusta
# Processing Record 31 of Set 13 | baruun-urt
# Processing Record 32 of Set 13 | solwezi
# Processing Record 33 of Set 13 | careiro da varzea
# Processing Record 34 of Set 13 | tiznit
# Processing Record 35 of Set 13 | neiafu
# Processing Record 36 of Set 13 | nioro
# Processing Record 37 of Set 13 | sijunjung
# Processing Record 38 of Set 13 | mende
# Processing Record 39 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | ures
# Processing Record 41 of Set 13 | bentiu
# Processing Record 42 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 43 of Set 13 | bibiani
# Processing Record 44 of Set 13 | nabire
# Processing Record 45 of Set 13 | tatarsk
# Processing Record 46 of Set 13 | gigmoto
# Processing Record 47 of Set 13 | suhbaatar
# Processing Record 48 of Set 13 | jalalabad
# Processing Record 49 of Set 13 | mayo
# Processing Record 50 of Set 13 | vanimo
# Processing Record 1 of Set 14 | hamilton
# Processing Record 2 of Set 14 | laguna de duero
# Processing Record 3 of Set 14 | verkhnevilyuysk
# Processing Record 4 of Set 14 | kamen-na-obi
# Processing Record 5 of Set 14 | touros
# Processing Record 6 of Set 14 | magrath
# Processing Record 7 of Set 14 | anadyr
# Processing Record 8 of Set 14 | tilichiki
# Processing Record 9 of Set 14 | trofors
# Processing Record 10 of Set 14 | sindou
# Processing Record 11 of Set 14 | leirvik
# Processing Record 12 of Set 14 | moose factory
# Processing Record 13 of Set 14 | ola
# Processing Record 14 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 14 | bosaso
# Processing Record 16 of Set 14 | greenville
# Processing Record 17 of Set 14 | verkhoyansk
# Processing Record 18 of Set 14 | churapcha
# Processing Record 19 of Set 14 | san luis
# Processing Record 20 of Set 14 | vestmanna
# Processing Record 21 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 14 | ternate
# Processing Record 24 of Set 14 | san jeronimo
# Processing Record 25 of Set 14 | elko
# Processing Record 26 of Set 14 | ahipara
# Processing Record 27 of Set 14 | pascagoula
# Processing Record 28 of Set 14 | chifeng
# Processing Record 29 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 14 | paciran
# Processing Record 31 of Set 14 | ambon
# Processing Record 32 of Set 14 | zhuhai
# Processing Record 33 of Set 14 | kurumkan
# Processing Record 34 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 14 | noyabrsk
# Processing Record 36 of Set 14 | callaway
# Processing Record 37 of Set 14 | quatre cocos
# Processing Record 38 of Set 14 | potsdam
# Processing Record 39 of Set 14 | paramonga
# Processing Record 40 of Set 14 | rognan
# Processing Record 41 of Set 14 | maryborough
# Processing Record 42 of Set 14 | kirchlengern
# Processing Record 43 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 14 | benghazi
# Processing Record 45 of Set 14 | bendigo
# Processing Record 46 of Set 14 | chardara
# Processing Record 47 of Set 14 | maragogi
# Processing Record 48 of Set 14 | antalaha
# Processing Record 49 of Set 14 | alirajpur
# Processing Record 50 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 15 | osorno
# Processing Record 2 of Set 15 | north bend
# Processing Record 3 of Set 15 | rehoboth
# Processing Record 4 of Set 15 | riachao das neves
# Processing Record 5 of Set 15 | eydhafushi
# Processing Record 6 of Set 15 | ust-nera
# Processing Record 7 of Set 15 | sibolga
# Processing Record 8 of Set 15 | porto novo
# Processing Record 9 of Set 15 | zacualpan
# Processing Record 10 of Set 15 | nizwa
# Processing Record 11 of Set 15 | fare
# Processing Record 12 of Set 15 | yuancheng
# Processing Record 13 of Set 15 | lagdo
# Processing Record 14 of Set 15 | elat
# Processing Record 15 of Set 15 | cepu
# Processing Record 16 of Set 15 | salamanca
# Processing Record 17 of Set 15 | sosnogorsk
# Processing Record 18 of Set 15 | canmore
# Processing Record 19 of Set 15 | padang
# Processing Record 20 of Set 15 | west bay
# Processing Record 21 of Set 15 | barcelona
# Processing Record 22 of Set 15 | cockburn town
# Processing Record 23 of Set 15 | russell
# Processing Record 24 of Set 15 | juegang
# Processing Record 25 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 15 | cullinan
# Processing Record 27 of Set 15 | san felipe
# Processing Record 28 of Set 15 | martapura
# Processing Record 29 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 15 | getahovit
# Processing Record 31 of Set 15 | milkovo
# Processing Record 32 of Set 15 | balikpapan
# Processing Record 33 of Set 15 | bella union
# Processing Record 34 of Set 15 | mtwara
# Processing Record 35 of Set 15 | ixtapa
# Processing Record 36 of Set 15 | namie
# Processing Record 37 of Set 15 | tongliao
# Processing Record 38 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | great falls
# Processing Record 40 of Set 15 | prieska
# Processing Record 41 of Set 15 | katha
# City not found. Skipping...
# Processing Record 42 of Set 15 | lilongwe
# Processing Record 43 of Set 15 | waitati
# Processing Record 44 of Set 15 | wajima
# Processing Record 45 of Set 15 | kiama
# Processing Record 46 of Set 15 | mogzon
# Processing Record 47 of Set 15 | bima
# Processing Record 48 of Set 15 | safaga
# Processing Record 49 of Set 15 | buckeye
# Processing Record 50 of Set 15 | aragarcas
# Processing Record 1 of Set 16 | malaya vishera
# Processing Record 2 of Set 16 | cosala
# Processing Record 3 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 5 of Set 16 | barentu
# Processing Record 6 of Set 16 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 16 | foix
# Processing Record 8 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 16 | mandalgovi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Rayagada      IN  19.1667   83.4167     76.68        94
# 1      Punta Arenas      CL -53.1500  -70.9167     41.11        93
# 2      Vila Do Maio      CV  15.1333  -23.2167     79.59        90
# 3       New Norfolk      AU -42.7826  147.0587     42.30        77
# 4       Clyde River      CA  70.4692  -68.5914     44.28        78
# ..              ...     ...      ...       ...       ...       ...
# 677  Malaya Vishera      RU  58.8454   32.2222     54.27        97
# 678          Cosala      MX  24.4125 -106.6908     78.12        78
# 679         Barentu      ER  15.1139   37.5928     71.08        85
# 680            Foix      FR  42.8333    1.5833     72.73        95
# 681      Mandalgovi      MN  45.7625  106.2708     65.05        59
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0            96        2.86     overcast clouds            0.0              0
# 1            90        4.61     overcast clouds            0.0              0
# 2            99        8.32     overcast clouds            0.0              0
# 3            87        1.99     overcast clouds            0.0              0
# 4            97        0.78     overcast clouds            0.0              0
# ..          ...         ...                 ...            ...            ...
# 677          34        8.19    scattered clouds            0.0              0
# 678          41        4.76    scattered clouds            0.0              0
# 679          70        5.19       broken clouds            0.0              0
# 680          71        3.60       broken clouds            0.0              0
# 681          71        9.55       broken clouds            0.0              0
#
# [682 rows x 11 columns]

# %%
# Show the snowing cities
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(15)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# show the raining cities 
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(15)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 10            Hobart      AU -42.8794  147.3294     42.66        88
# 22           Qaanaaq      GL  77.4840  -69.3632     38.07        99
# 25              Nuuk      GL  64.1835  -51.7216     47.01       100
# 27           Kahului      US  20.8947 -156.4700     85.96        69
# 34    Saint-Philippe      RE -21.3585   55.7679     63.95        74
# 40      Norman Wells      CA  65.2820 -126.8329     59.04        77
# 43            Narsaq      GL  60.9167  -46.0500     50.22        98
# 62   Bambous Virieux      MU -20.3428   57.7575     68.25        83
# 73    Virginia Beach      US  36.8529  -75.9780     80.02        83
# 76             Raton      US  36.9034 -104.4391     74.01        43
# 82           Te Anau      NZ -45.4167  167.7167     42.82        96
# 96        Port Blair      IN  11.6667   92.7500     79.88        82
# 105           Koslan      RU  63.4564   48.8989     57.96        94
# 113          Bubaque      GW  11.2833  -15.8333     78.40        82
# 119         Am Timan      TD  11.0297   20.2827     72.32        94
#
#      Cloudiness  Wind Speed          Current Description  Rain (inches)  \
# 10           75        4.00                  shower rain           0.10
# 22          100        5.61                   light rain           0.29
# 25           90       12.66  light intensity shower rain           0.40
# 27           40       20.71                   light rain           0.16
# 34           87       12.46                   light rain           0.13
# 40           75        2.30                   light rain           0.22
# 43           99        4.59                moderate rain           1.11
# 62           40       10.36                   light rain           0.35
# 73          100        3.00                   light rain           0.36
# 76            1        1.99                   light rain           0.24
# 82           86       10.22                moderate rain           1.97
# 96          100       12.41                moderate rain           2.73
# 105         100        7.67                moderate rain           2.05
# 113         100        9.40                moderate rain           1.09
# 119          47        3.20                   light rain           0.27
#
#      Snow (inches)
# 10               0
# 22               0
# 25               0
# 27               0
# 34               0
# 40               0
# 43               0
# 62               0
# 73               0
# 76               0
# 82               0
# 96               0
# 105              0
# 113              0
# 119              0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# And thats all, folks!
